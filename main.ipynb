# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

import floorplan_reader

# %%
image = floorplan_reader.process_image('plans/floorplan_04.png')
image
# Out:
# <PIL.Image.Image image mode=RGB size=1513x1200 at 0x7F991FDA2790>

# %%
df_rooms = floorplan_reader.process_floorplan('plans/floorplan_04.png', resize_factor = 5)
df_rooms
# Out:
#              room  side_a  side_b      size
# 0          GARDEN   24.32   10.67  259.4944
# 1    CONSERVATORY    3.56    2.62    9.3272
# 2           STUDY    2.31    2.62    6.0522
# 3     DINING ROOM    3.51    3.05   10.7055
# 4       BEDROOM 4    3.25    2.31    7.5075
# 5         KITCHEN    5.08    2.26   11.4808
# 6  RECEPTION ROOM    5.00    3.51   17.5500
# 7       BEDROOM 2    3.53    3.33   11.7549
# 8       BEDROOM 1    4.88    3.53   17.2264
# 9       BEDROOM 3    2.87    2.29    6.5723

# %%
image = floorplan_reader.process_image('plans/floorplan_01.jpeg')
image
# Out:
# <PIL.Image.Image image mode=RGB size=1600x1178 at 0x7F990C9B5250>

# %%
df_rooms = floorplan_reader.process_floorplan('plans/floorplan_01.jpeg', resize_factor = 5)
df_rooms
# Out:
#           room  side_a  side_b     size
# 0  DINING ROOM    2.74    2.56   7.0144
# 1      KITCHEN    3.24    2.72   8.8128
# 2    BEDROOM 2    3.45    2.72   9.3840
# 3      UTILITY    1.96    1.50   2.9400
# 4  LIVING ROOM    4.18    3.51  14.6718
# 5    BEDROOM 1    3.62    3.42  12.3804
# 6    BEDROOM 3    2.71    2.37   6.4227

# %%
image = floorplan_reader.process_image('plans/floorplan_02.png')
image
# Out:
# <PIL.Image.Image image mode=RGB size=2221x1800 at 0x7FEBD6067310>

# %%
df_rooms = floorplan_reader.process_floorplan('plans/floorplan_02.png', resize_factor = 3)
df_rooms
# Out:
#              room  side_a  side_b     size
# 0   KITCHEN/DINER    4.74    3.55  16.8270
# 1  MASTER BEDROOM    3.14    2.95   9.2630
# 2    SITTING ROOM    3.69    4.74  17.4906
# 3       BEDROOM 2    2.47    3.66   9.0402
# 4       BEDROOM 3    2.17    2.56   5.5552

# %%
image = floorplan_reader.process_image('plans/floorplan_03.jpeg')
image
# Out:
# <PIL.Image.Image image mode=RGB size=1600x510 at 0x7FF1DA0DA090>

# %%
df_rooms = floorplan_reader.process_floorplan('plans/floorplan_03.jpeg', resize_factor = 5)
df_rooms
# Out:
#            room  side_a  side_b     size
# 0       UTILITY    2.51    2.44   6.1244
# 1  SITTING ROOM    7.01    3.66  25.6566
# 2     BEDROOM 1    3.10    3.00   9.3000
# 3     BEDROOM 2    3.10    3.05   9.4550
# 4     BEDROOM 4    3.66    3.23  11.8218
# 5     BEDROOM 3    3.23    2.92   9.4316
